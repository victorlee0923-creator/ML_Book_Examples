# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('creditcard.csv')
print(df.shape)
df.head(5)
# Out:
# (28481, 31)
#    Time    V1    V2    V3    V4    V5    V6    V7    V8    V9  ...   V21  \
# 0     0  1.19  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -0.23
# 1     4  1.23  0.14  0.05  1.20  0.19  0.27 -0.01  0.08  0.46  ... -0.17
# 2     7 -0.89  0.29 -0.11 -0.27  2.67  3.72  0.37  0.85 -0.39  ... -0.07
# 3    11  1.07  0.29  0.83  2.71 -0.18  0.34 -0.10  0.12 -0.22  ... -0.04
# 4    16  0.69 -1.36  1.03  0.83 -1.19  1.31 -0.88  0.45 -0.45  ... -0.30
#
#     V22   V23   V24   V25   V26   V27   V28  Amount  Class
# 0 -0.64  0.10 -0.34  0.17  0.13 -0.01  0.01    2.69      0
# 1 -0.27 -0.15 -0.78  0.75 -0.26  0.03  0.01    4.99      0
# 2 -0.27 -0.20  1.01  0.37 -0.38  0.01  0.14   93.20      0
# 3  0.07 -0.07  0.10  0.55  0.10  0.02  0.02   27.50      0
# 4 -0.57 -0.05 -0.30  0.07 -0.42  0.09  0.06  231.71      0
#
# [5 rows x 31 columns]

# %%
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count   28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean    94705.035216     -0.001136     -0.018281      0.000810      0.000331
# std     47584.727034      1.994678      1.709050      1.522291      1.420023
# min         0.000000    -40.470000    -63.340000    -31.810000     -5.270000
# 25%     53924.000000     -0.910000     -0.610000     -0.890000     -0.850000
# 50%     84551.000000      0.030000      0.050000      0.180000     -0.020000
# 75%    139392.000000      1.320000      0.790000      1.040000      0.740000
# max    172784.000000      2.410000     17.420000      4.070000     16.720000
#
#                  V5            V6            V7            V8            V9  \
# count  28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean      -0.015688      0.003662     -0.008532     -0.003054      0.014535
# std        1.395562      1.334965      1.237232      1.204101      1.097965
# min      -42.150000    -20.000000    -22.290000    -33.790000     -8.740000
# 25%       -0.700000     -0.770000     -0.560000     -0.210000     -0.630000
# 50%       -0.070000     -0.270000      0.030000      0.020000     -0.040000
# 75%        0.600000      0.400000      0.560000      0.330000      0.620000
# max       28.760000     22.530000     36.680000     19.590000      8.140000
#
#        ...           V21           V22           V23           V24  \
# count  ...  28481.000000  28481.000000  28481.000000  28481.000000
# mean   ...      0.004747      0.006717     -0.000522     -0.002626
# std    ...      0.744764      0.728238      0.645977      0.603983
# min    ...    -16.640000    -10.930000    -30.270000     -2.750000
# 25%    ...     -0.220000     -0.540000     -0.160000     -0.360000
# 50%    ...     -0.030000      0.010000     -0.010000      0.040000
# 75%    ...      0.190000      0.530000      0.150000      0.430000
# max    ...     22.590000      6.090000     15.630000      3.940000
#
#                 V25           V26           V27           V28        Amount  \
# count  28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean      -0.000921      0.004791     -0.001694     -0.004140     89.957884
# std        0.520669      0.488182      0.418341      0.321653    270.894630
# min       -7.030000     -2.530000     -8.260000     -9.620000      0.000000
# 25%       -0.320000     -0.330000     -0.070000     -0.050000      5.980000
# 50%        0.020000     -0.050000      0.000000      0.010000     22.350000
# 75%        0.350000      0.250000      0.090000      0.080000     78.930000
# max        5.540000      3.120000     11.140000     15.370000  19656.530000
#
#               Class
# count  28481.000000
# mean       0.001720
# std        0.041443
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
plt.pie(df.Class.value_counts(), autopct='%1.1f%%', 
        labels=['Genuine','Fraud'])
plt.axis('equal')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# 看看時間上是否有關連
print("Time variable")
df["Time_Hr"] = df["Time"]/3600 # 轉換成小時

fig, (ax1, ax2) = plt.subplots(2, 1, sharex = True, figsize=(8, 5))
ax1.hist(df.Time_Hr[df.Class==0], bins=48, color='g', alpha=0.5)
ax1.set_title('Genuine')
ax2.hist(df.Time_Hr[df.Class==1], bins=48, color='r', alpha=0.5)
ax2.set_title('Fraud')
plt.xlabel('Time (hrs)')
plt.ylabel('# transactions')
# Out:
# Time variable
# Text(0, 0.5, '# transactions')

# %%
from sklearn.preprocessing import StandardScaler

df['Amount'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['Class'],axis=1).values
y = df['Class'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()
clf.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import classification_report
# 產生分類報告
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5686
#            1       0.17      0.64      0.27        11
#
#     accuracy                           0.99      5697
#    macro avg       0.59      0.82      0.63      5697
# weighted avg       1.00      0.99      1.00      5697

# %%
clf.predict_proba(X_test)
# Out:
# array([[1.00000000e+00, 1.44302015e-11],
#        [1.00000000e+00, 8.57459791e-12],
#        [1.00000000e+00, 1.56252974e-12],
#        ...,
#        [1.00000000e+00, 5.54241052e-12],
#        [1.00000000e+00, 2.90454587e-12],
#        [1.00000000e+00, 1.17271889e-12]])
